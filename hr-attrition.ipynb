# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/kaggle/input/hr-employee-attrition/HR-Employee-Attrition.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# This involves a series from;
#
# * Deleting redundant columns.
# * Renaming the columns.
# * Dropping duplicates.
# * Cleaning individual columns.
# * Remove the NaN values from the dataset

# %%
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Check for duplicates and drop them.

# %%
data_copy = data.copy()
Employee = data_copy[['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
duplicates = Employee[Employee[['EmployeeNumber']].duplicated()]
Employee = Employee.drop(duplicates.index.tolist())
Employee.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Gender Count

# %%
data.groupby(['EmployeeCount']).size()
# Out:
# EmployeeCount
# 1    1470
# dtype: int64

# %%
ax = sns.countplot(data=data,x='Gender')
sns.countplot(x= "Gender", hue="Gender", order=[1, 0], data = data).set(xticklabels = [])
plt.ylabel("Count")
plt.title("Gender Comparison")
plt.show()

# %%
ax = sns.countplot(data=data,x='Gender')
sns.countplot(x= "Gender", hue="Gender", order=[1, 0], data = data).set(xticklabels = [])
plt.ylabel("Count")
plt.title("Gender Comparison")
plt.show()

# %% [markdown]
# ## Attrition by Gender

# %%
data.groupby(['Gender','Attrition']).size()
# Out:
# Gender  Attrition
# Female  No           501
#         Yes           87
# Male    No           732
#         Yes          150
# dtype: int64

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Attrition", hue="Gender", data=data)

# %% [markdown]
# Male employees have a higher negative Attrition at 150 employee voting yes compared to female at 59.

# %% [markdown]
# ## Attrition by Department

# %%
data.groupby(['Department','Attrition']).size()
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Attrition", hue="Department", data=data)

# %% [markdown]
# ## Attrition by Job Role

# %%
data.groupby(['JobRole','Attrition']).size()
# Out:
# JobRole                    Attrition
# Healthcare Representative  No           122
#                            Yes            9
# Human Resources            No            40
#                            Yes           12
# Laboratory Technician      No           197
#                            Yes           62
# Manager                    No            97
#                            Yes            5
# Manufacturing Director     No           135
#                            Yes           10
# Research Director          No            78
#                            Yes            2
# Research Scientist         No           245
#                            Yes           47
# Sales Executive            No           269
#                            Yes           57
# Sales Representative       No            50
#                            Yes           33
# dtype: int64

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Attrition", hue="JobRole", data=data)

# %% [markdown]
# ## Attrition by Years Since Last Promotion

# %%
data.groupby(['Attrition','YearsSinceLastPromotion']).size()
# Out:
# Attrition  YearsSinceLastPromotion
# No         0                          471
#            1                          308
#            2                          132
#            3                           43
#            4                           56
#            5                           43
#            6                           26
#            7                           60
#            8                           18
#            9                           13
#            10                           5
#            11                          22
#            12                          10
#            13                           8
#            14                           8
#            15                          10
# Yes        0                          110
#            1                           49
#            2                           27
#            3                            9
#            4                            5
# ...

# %% [markdown]
# ## Attrition by Number of Years in the Company

# %%
data.groupby(['YearsAtCompany','Attrition']).size()
# Out:
# YearsAtCompany  Attrition
# 0               No            28
#                 Yes           16
# 1               No           112
#                 Yes           59
# 2               No           100
#                             ...
# 33              Yes            1
# 34              No             1
# 36              No             2
# 37              No             1
# 40              Yes            1
# Length: 64, dtype: int64

# %% [markdown]
# ## Attrition by Job Satisfaction

# %%
data.groupby(['JobSatisfaction','Attrition']).size()
# Out:
# JobSatisfaction  Attrition
# 1                No           223
#                  Yes           66
# 2                No           234
#                  Yes           46
# 3                No           369
#                  Yes           73
# 4                No           407
#                  Yes           52
# dtype: int64

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Attrition", hue="JobSatisfaction", data=data)

# %% [markdown]
# ## Attrition by Work Life Balance

# %%
data.groupby(['WorkLifeBalance','EnvironmentSatisfaction','Attrition']).size()
# Out:
# WorkLifeBalance  EnvironmentSatisfaction  Attrition
# 1                1                        No            11
#                                           Yes            9
#                  2                        No            10
#                                           Yes            3
#                  3                        No            18
#                                           Yes            4
#                  4                        No            16
#                                           Yes            9
# 2                1                        No            56
#                                           Yes           11
#                  2                        No            65
#                                           Yes           13
#                  3                        No            82
#                                           Yes           18
#                  4                        No            83
# ...

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="WorkLifeBalance", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Standard Working Hours

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="StandardHours", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Field of Education

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="EducationField", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Job Satisfaction

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="JobSatisfaction", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Years Since Last Promotion

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="YearsSinceLastPromotion", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Years in current Role

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="YearsInCurrentRole", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Current Manager

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="YearsWithCurrManager", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Salary Hike

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="PercentSalaryHike", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Marital Status

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="MaritalStatus", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Job Level

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="JobLevel", hue="Attrition", data=data)

# %% [markdown]
# ## Attrition by Over Time

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="OverTime", hue="Attrition", data=data)

# %% [markdown]
# ## Correlation Matrix

# %%
cols=['Age','DailyRate', 'HourlyRate', 'JobLevel',
       'MonthlyIncome', 'MonthlyRate', 'PercentSalaryHike', 'TotalWorkingYears','YearsInCurrentRole','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager']
correlation_matrix = data[cols].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='hot', linewidths=.5)
plt.show()
